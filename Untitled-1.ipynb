# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df=df.set_index('PassengerId')

# %%
df['Parch'].plot(kind='hist')
plt.title('Histogram of No.Parents on Board')
plt.xlabel('no. of parents')
# Out:
# Text(0.5, 0, 'no. of parents')

# %%
df['Fare'].plot(kind='line')
plt.title('Fare Paid')
plt.ylabel('Price in British Pound')
# Out:
# Text(0, 0.5, 'Price in British Pound')

# %%
df_Pclass=df.set_index('Pclass')
df_Pclass
# Out:
#         Survived                                          Name     Sex   Age  \
# Pclass
# 3              0                              Kelly, Mr. James    male  34.5
# 3              1              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2              0                     Myles, Mr. Thomas Francis    male  62.0
# 3              0                              Wirz, Mr. Albert    male  27.0
# 3              1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ...          ...                                           ...     ...   ...
# 3              0                            Spector, Mr. Woolf    male   NaN
# 1              1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 3              0                  Saether, Mr. Simon Sivertsen    male  38.5
# 3              0                           Ware, Mr. Frederick    male   NaN
# 3              0                      Peter, Master. Michael J    male   NaN
#
#         SibSp  Parch              Ticket      Fare Cabin Embarked
# Pclass
# 3           0      0              330911    7.8292   NaN        Q
# 3           1      0              363272    7.0000   NaN        S
# 2           0      0              240276    9.6875   NaN        Q
# 3           0      0              315154    8.6625   NaN        S
# 3           1      1             3101298   12.2875   NaN        S
# ...       ...    ...                 ...       ...   ...      ...
# 3           0      0           A.5. 3236    8.0500   NaN        S
# 1           0      0            PC 17758  108.9000  C105        C
# 3           0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 3           0      0              359309    8.0500   NaN        S
# 3           1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
df_Pclass=df.groupby('Pclass').count()

# %%
df_Pclass['Name'].plot(kind='pie')
plt.title('passenger class')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df_sex=df.set_index('Sex')
df_sex
# Out:
#         Survived  Pclass                                          Name   Age  \
# Sex
# male           0       3                              Kelly, Mr. James  34.5
# female         1       3              Wilkes, Mrs. James (Ellen Needs)  47.0
# male           0       2                     Myles, Mr. Thomas Francis  62.0
# male           0       3                              Wirz, Mr. Albert  27.0
# female         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ...          ...     ...                                           ...   ...
# male           0       3                            Spector, Mr. Woolf   NaN
# female         1       1                  Oliva y Ocana, Dona. Fermina  39.0
# male           0       3                  Saether, Mr. Simon Sivertsen  38.5
# male           0       3                           Ware, Mr. Frederick   NaN
# male           0       3                      Peter, Master. Michael J   NaN
#
#         SibSp  Parch              Ticket      Fare Cabin Embarked
# Sex
# male        0      0              330911    7.8292   NaN        Q
# female      1      0              363272    7.0000   NaN        S
# male        0      0              240276    9.6875   NaN        Q
# male        0      0              315154    8.6625   NaN        S
# female      1      1             3101298   12.2875   NaN        S
# ...       ...    ...                 ...       ...   ...      ...
# male        0      0           A.5. 3236    8.0500   NaN        S
# female      0      0            PC 17758  108.9000  C105        C
# male        0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# male        0      0              359309    8.0500   NaN        S
# male        1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
df_scount=df.groupby('Sex').count()
df_scount
# Out:
#         Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Sex
# female       152     152   152  127    152    152     152   152     44
# male         266     266   266  205    266    266     266   265     47
#
#         Embarked
# Sex
# female       152
# male         266

# %%
df_scount['Name'].plot(kind='pie')
plt.title('female or male ')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
